# %%
# Add the parent directory to the Python path
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), '../'))

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')


from src.graph_analysis import GraphMetrics

# %%
graph_metrics = GraphMetrics()

# %%
cbg_path = '../../results/graph_features/Schaefer2018_100Parcels_7Networks/adults_cross_correlation_statmodels_global_graph_features.h5'

metric, names = graph_metrics.load_from_h5(cbg_path)

# %%
metric
# Out:
# array([[ 0.06429987,  0.41413881,  2.95632699,  2.77518221,  0.07353535,
#          4.        ,  6.        ,  0.43653846,  0.14745852],
#        [ 0.19056017,  0.56302519,  1.8969697 ,  1.66573191,  0.24909091,
#          2.        ,  4.        ,  0.53098114,  0.29680241],
#        [ 0.2187022 ,  0.23362698,  3.54449783,  3.36309269,  0.04505051,
#          5.        ,  8.        ,  0.28039927,  0.07011976],
#        [ 0.4438162 ,  0.34624376,  3.48498168,  3.40435798,  0.05676768,
#          5.        ,  9.        ,  0.44134615,  0.09971949],
#        [ 0.3199442 ,  0.26576889,  3.13269275,  3.03941147,  0.05434343,
#          4.        ,  7.        ,  0.34380165,  0.09025234],
#        [ 0.26820395,  0.384971  ,  3.11564626,  2.64034199,  0.07757576,
#          5.        ,  7.        ,  0.44228206,  0.12480865],
#        [ 0.42461883,  0.337381  ,  2.6921944 ,  2.41526251,  0.08747475,
#          4.        ,  6.        ,  0.41533406,  0.12787573],
# ...
